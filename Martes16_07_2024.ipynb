# %% [markdown]
# <a href="https://colab.research.google.com/github/Alejandra09MZ/inteligenciaArtificial/blob/main/Martes16_07_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import Index
import numpy as np
import pandas as pd
print (pd.__version__)


serieData=pd.Series(data=[100,200,300],index=['juan','pedro','lucas'])
print(serieData)
print('.........')
print(serieData['juan'])

print(serieData.index)
print('pedro' in serieData)

# ESTRUCTURA DE DATOS EN 2 DIMENCIONES
myDictionary={'one':pd.Series([100,200,300],index=['juan','pedro','lucas']),
              'two':pd.Series([11,22,33],index=['julio','pedro','lucas'])}

# SERIES AND DATAFRAME
df=pd.DataFrame(myDictionary)
print(df)

print('We are here........')
print(df.index)
print(df.columns)

print(df.loc['juan'])
# Out:
# 2.0.3
# juan     100
# pedro    200
# lucas    300
# dtype: int64
# .........
# 100
# Index(['juan', 'pedro', 'lucas'], dtype='object')
# True
#          one   two
# juan   100.0   NaN
# julio    NaN  11.0
# lucas  300.0  33.0
# pedro  200.0  22.0
# We are here........
# Index(['juan', 'julio', 'lucas', 'pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# one    100.0
# two      NaN
# Name: juan, dtype: float64

# %%
# JUEVES 18 DE JULIO 2024

# %%
import pandas as pd
df=pd.read_csv('/content/ratings.csv')

# %%
df
# Out:
#          userId  movieId  rating     timestamp
# 0             1    296.0     5.0  1.147880e+09
# 1             1    306.0     3.5  1.147869e+09
# 2             1    307.0     5.0  1.147869e+09
# 3             1    665.0     5.0  1.147879e+09
# 4             1    899.0     3.5  1.147869e+09
# ...         ...      ...     ...           ...
# 5925792   38409   1840.0     3.0  9.398815e+08
# 5925793   38409   1873.0     3.0  9.398804e+08
# 5925794   38409   1884.0     4.0  9.398822e+08
# 5925795   38409   1898.0     3.0  9.513941e+08
# 5925796    3840      NaN     NaN           NaN
#
# [5925797 rows x 4 columns]

# %%
df.head(6)
# Out:
#    userId  movieId  rating     timestamp
# 0       1    296.0     5.0  1.147880e+09
# 1       1    306.0     3.5  1.147869e+09
# 2       1    307.0     5.0  1.147869e+09
# 3       1    665.0     5.0  1.147879e+09
# 4       1    899.0     3.5  1.147869e+09
# 5       1   1088.0     4.0  1.147868e+09

# %%
del df['timestamp']

# %%
df
# Out:
#          userId  movieId  rating
# 0             1    296.0     5.0
# 1             1    306.0     3.5
# 2             1    307.0     5.0
# 3             1    665.0     5.0
# 4             1    899.0     3.5
# ...         ...      ...     ...
# 5925792   38409   1840.0     3.0
# 5925793   38409   1873.0     3.0
# 5925794   38409   1884.0     4.0
# 5925795   38409   1898.0     3.0
# 5925796    3840      NaN     NaN
#
# [5925797 rows x 3 columns]

# %%
df.shape
# Out:
# (5925797, 3)

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5925797, step=1)

# %%
tmp=df.iloc[255]

# %%
tmp
# Out:
# userId      3.0
# movieId    29.0
# rating      4.5
# Name: 255, dtype: float64

# %%
tmp['userId']
# Out:
# 3.0

# %%
'rating' in df.columns
# Out:
# True

# %%
df.iloc[[100,200,300]]
# Out:
#      userId  movieId  rating
# 100       2   1080.0     1.0
# 200       2   4886.0     5.0
# 300       3   1320.0     3.5

# %%
df.describe()
# Out:
#              userId       movieId        rating
# count  5.925797e+06  5.925796e+06  5.925796e+06
# mean   1.948501e+04  2.158303e+04  3.530313e+00
# std    1.105770e+04  3.946769e+04  1.062111e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    9.883000e+03  1.197000e+03  3.000000e+00
# 50%    1.953600e+04  2.959000e+03  3.500000e+00
# 75%    2.918500e+04  8.639000e+03  4.000000e+00
# max    3.840900e+04  2.091630e+05  5.000000e+00

# %%
movies=pd.read_csv('/content/movies.csv')
ratings=pd.read_csv('/content/ratings.csv')
tags=pd.read_csv('/content/tags.csv')

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating     timestamp
# 0       1    296.0     5.0  1.147880e+09
# 1       1    306.0     3.5  1.147869e+09

# %%
tags.head(2)
# Out:
#    userId  movieId      tag   timestamp
# 0       3      260  classic  1439472355
# 1       3      260   sci-fi  1439472256

# %%
# COMO ELIMINAR
del ratings['timestamp']
del tags['timestamp']

# %%
print(movies.shape)
print(ratings.shape)
print(tags.shape)
# Out:
# (62423, 3)
# (5925797, 3)
# (1093360, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId     True
# rating      True
# dtype: bool

# %%
print(tags.shape)
aux1=tags.shape[0]
tags=tags.dropna()
aux2=tags.shape[0]
print(aux1)
print(tags.shape)
print(f'Muestras eliminadas en variable tag',(aux1-aux2))
# Out:
# (1093360, 3)
# 1093360
# (1093344, 3)
# Muestras eliminadas en variable tag 16

# %%
print(ratings.columns)
print(ratings['rating'].max())
print(f'Numero de muestra antes del filtro {ratings.shape}')
print(ratings['rating'].min())
calificacion_aLlta=ratings['rating']>=4
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')
# 5.0
# Numero de muestra antes del filtro (5925797, 3)
# 0.5

# %%
ratings_despues=ratings[calificacion_aLlta]
print("Numero de muestra despues del filtro",ratings_despues.shape)
# Out:
# Numero de muestra despues del filtro (2939471, 3)
