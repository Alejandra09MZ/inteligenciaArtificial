# %% [markdown]
# <a href="https://colab.research.google.com/github/Alejandra09MZ/inteligenciaArtificial/blob/main/Leccion2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use this line to load the dataset.
import pandas as pd
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
df
# Out:
#          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# [1145586 rows x 5 columns]

# %%
df
# Out:
#          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# [1145586 rows x 5 columns]

# %%
# for basic exploration, we suggest to use shape, head(), tail(), dtypes, type() modules
# Para la exploración básica, sugerimos usar los módulos shape, head(), tail(), dtypes, type()
df.shape
# Out:
# (1145586, 5)

# %%
# Muestra las últimas filas del DataFrame
df.tail
# Out:
# <bound method NDFrame.tail of          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# [1145586 rows x 5 columns]>

# %%
#  Muestra el tipo de datos de cada columna.
df.dtypes
# Out:
# station_id      int64
# stationname    object
# date           object
# daytype        object
# rides           int64
# dtype: object

# %%
# Muestra el tipo de datos del DataFrame.
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# use the describe module
df.describe()
pass

# %%
df
# Out:
#          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# [1145586 rows x 5 columns]

# %%
# use the min() and max() modules
max_rides = df['rides'].max()
min_rides = df['rides'].min()

print(f"El máximo es: {max_rides}")
print(f"El mínimo es: {min_rides}")
# Out:
# El máximo es: 36323
# El mínimo es: 0

# %%
# Cargar el DataFrame desde el URL proporcionado
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)

# Convertir la columna 'date' al tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Establecer la columna 'date' como índice del DataFrame
df.set_index('date', inplace=True)

# Mostrar las primeras filas del DataFrame con el nuevo índice de tiempo
print("\nDataFrame con índice de tiempo:")
print(df.head())
# Out:
# DataFrame con índice de tiempo:
#             station_id       stationname daytype  rides
# date
# 2017-12-22       41280    Jefferson Park       W   6104
# 2017-12-18       41000  Cermak-Chinatown       W   3636
# 2017-12-02       40280      Central-Lake       A   1270
# 2017-12-19       40140   Dempster-Skokie       W   1759
# 2017-12-03       40690          Dempster       U    499

# %%
# Cargar el DataFrame desde el URL proporcionado
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)

# Convertir la columna 'date' al tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Establecer la columna 'date' como índice del DataFrame
df.set_index('date', inplace=True)

# Mostrar las primeras filas del DataFrame con el nuevo índice de tiempo
print("\nDataFrame con índice de tiempo:")
print(df.head())
# Out:
# DataFrame con índice de tiempo:
#             station_id       stationname daytype  rides
# date
# 2017-12-22       41280    Jefferson Park       W   6104
# 2017-12-18       41000  Cermak-Chinatown       W   3636
# 2017-12-02       40280      Central-Lake       A   1270
# 2017-12-19       40140   Dempster-Skokie       W   1759
# 2017-12-03       40690          Dempster       U    499

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv')

# Filtrar el DataFrame para las filas donde 'stationname' es igual a 'Garfield-Dan Ryan'
Garfield_Dan_Ryan = df[df['stationname'] == 'Garfield-Dan Ryan']

# Imprimir el DataFrame filtrado
print(Garfield_Dan_Ryan)
# Out:
#          station_id        stationname        date daytype  rides
# 152           41170  Garfield-Dan Ryan  12/22/2017       W   3040
# 501           41170  Garfield-Dan Ryan  12/05/2017       W   3217
# 645           41170  Garfield-Dan Ryan  12/27/2017       W   2016
# 910           41170  Garfield-Dan Ryan  12/02/2017       A   2624
# 1034          41170  Garfield-Dan Ryan  12/19/2017       W   2958
# ...             ...                ...         ...     ...    ...
# 1144465       41170  Garfield-Dan Ryan  12/27/2022       W    976
# 1144466       41170  Garfield-Dan Ryan  12/28/2022       W    961
# 1144467       41170  Garfield-Dan Ryan  12/29/2022       W    991
# 1144468       41170  Garfield-Dan Ryan  12/30/2022       W   1135
# 1144469       41170  Garfield-Dan Ryan  12/31/2022       A    776
#
# [8005 rows x 5 columns]

# %%
# Cargar el conjunto de datos en un DataFrame
# Reemplaza 'tu_archivo.csv' con la ruta real o URL de tu conjunto de datos
df = pd.read_csv('https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv')

# Convertir la columna 'date' al formato datetime
df['date'] = pd.to_datetime(df['date'])

# Establecer la columna 'date' como índice del DataFrame
df.set_index('date', inplace=True)

# Ordenar el DataFrame por la columna de fecha ('date')
df.sort_values(by='date', inplace=True)

# Imprimir el DataFrame ordenado por fecha
print(df)
# Out:
#             station_id         stationname daytype  rides
# date
# 2001-01-01       41290             Kimball       U    869
# 2001-01-01       40090         Damen-Brown       U    411
# 2001-01-01       40850             Library       U    156
# 2001-01-01       40650      North/Clybourn       U   1156
# 2001-01-01       40290        Ashland/63rd       U    540
# ...                ...                 ...     ...    ...
# 2022-12-31       41660          Lake/State       A   5491
# 2022-12-31       41000    Cermak-Chinatown       A   2055
# 2022-12-31       40400               Noyes       A    121
# 2022-12-31       40970  Cicero-Forest Park       A    349
# 2022-12-31       41700   Washington/Wabash       A   2774
#
# [1145586 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Establecer el tamaño de las figuras usando seaborn
sns.set(rc={'figure.figsize':(11, 4)})

# Suponiendo que Garfield_Dan_Ryan es tu DataFrame con los datos filtrados
# Reemplaza 'rides' con el nombre real de la columna en tu DataFrame
# Garfield_Dan_Ryan['rides'].plot(linewidth=0.5)

# Ejemplo de trazado de una serie temporal de rides (viajes)
plt.plot(Garfield_Dan_Ryan.index, Garfield_Dan_Ryan['rides'], linewidth=0.5)

# Personalización del gráfico
plt.title('Número de Viajes en Garfield-Dan Ryan')  # Título del gráfico
plt.xlabel('Fecha')  # Etiqueta del eje x
plt.ylabel('Número de Viajes')  # Etiqueta del eje y
plt.grid(True)  # Habilitar cuadrícula en el gráfico
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mejor visualización

# Mostrar el gráfico
plt.tight_layout()  # Ajustar diseño para evitar superposición de elementos
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd # Import pandas for DataFrame manipulation

# Establecer el tamaño de las figuras usando seaborn
sns.set(rc={'figure.figsize':(11, 4)})

# Load the dataset (replace with your actual file path or URL)
df = pd.read_csv('https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv')

# Filter the DataFrame for 'Garfield-South Elevated' station
Garfield_South_Elevated = df[df['stationname'] == 'Garfield-South Elevated']

# Convert 'date' column to datetime and set it as index
Garfield_South_Elevated['date'] = pd.to_datetime(Garfield_South_Elevated['date'])
Garfield_South_Elevated.set_index('date', inplace=True)

# Now you can plot the data
plt.plot(Garfield_South_Elevated.index, Garfield_South_Elevated['rides'], linewidth=0.5)

# Personalización del gráfico
plt.title('Número de Viajes en Garfield-South Elevated')  # Título del gráfico
plt.xlabel('Fecha')  # Etiqueta del eje x
plt.ylabel('Número de Viajes')  # Etiqueta del eje y
plt.grid(True)  # Habilitar cuadrícula en el gráfico
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mejor visualización

# Mostrar el gráfico
plt.tight_layout()  # Ajustar diseño para evitar superposición de elementos
plt.show()
# Out:
# <ipython-input-15-68646520dbe3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Garfield_South_Elevated['date'] = pd.to_datetime(Garfield_South_Elevated['date'])
